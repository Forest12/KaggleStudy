# %% [markdown]
# <a href="https://colab.research.google.com/github/Forest12/KaggleStudy/blob/main/20230727_KaggleTest1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib as mpl
mpl.__version__
# Out:
# '3.7.1'

# %%
import numpy as np
np.__version__
# Out:
# '1.22.4'

# %%
import nltk

nltk.__version__
# Out:
# '3.8.1'

# %%
import pandas as pd
pd.__version__
# Out:
# '1.5.3'

# %%
import numpy as np
np.__version__
# Out:
# '1.22.4'

# %%
import matplotlib as mpl
mpl.__version__
import matplotlib.pyplot as plt

# %%
plt.title('test')
plt.plot([1,2,3,4],[2,4,8,6])
plt.show()

# %%
plt.title('test')
plt.plot([1,2,3,4],[2,4,8,6])
plt.xlabel('hours')
plt.ylabel('score')
plt.show()

# %%
plt.title('test')
plt.plot([1,2,3,4],[2,4,8,6])
plt.plot([1.5,2.5,3.5,4.5],[3,5,8,10])
plt.xlabel('hours')
plt.ylabel('score')
plt.legend(['a','b'])
plt.show()
